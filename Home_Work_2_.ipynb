# %% [markdown]
# <a href="https://colab.research.google.com/github/Khafiz246810/CSE203-Data-structure-/blob/main/Home_Work_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1

class Stack():
    def __init__(self):
        self.item=[]

    def push(self,item):
        self.item.append(item)

    def pop(self):
        return self.item.pop()

    def peek(self):
        if not len(self.item)==0:
            return self.item[-1]

    def get_all(self):
        return self.item


def reverse_string(val):
    stack = Stack()
    for char in range(len(val)):
        stack.push(val[char])

    update_str=" "
    while not (len(stack.get_all())==0):
        update_str += stack.pop()
    return update_str
name=input("Input: ")
x=reverse_string(name)
print("Output:",x)
# Out:
# Input: W A T E R M E L O N
# Output:  N O L E M R E T A W

# %%
#2

def isBalanced(a):
    stack = []

    for i in (a):
        if i in ["(", "{", "["]:
            stack.append(a)
        else:
            if not stack:
                return False
            current_a=stack.pop()
            if current_a == '(':
                if a != ')':
                    return False
            if current_a == '{':
                if a!= '}':
                    return False
            if current_a == '[':
                if a != ']':
                    return False
    if stack:
        return False
    else:
        return True
a = input("Input:")
x=isBalanced(a)
print("Output:",x)
# Out:
# Input:()
# Output: True

# %%
#3

class Stack():
    def __init__(self):
        self.item=[]
    def size(self):
        l=len(self.item)
        return l

    def isempty(self):
        if self.size()==0:
            return 1
        else:
            False
    def push(self,item):
        self.item.append(item)

    def pop(self):
        return self.item.pop()

    def peek(self):
        if not len(self.item)==0:
            return self.item[-1]

    def get_all(self):
        return self.item

def needmax(k,s):

    max=k.peek()
    for i in range(k.size()):
        if max<k.get_all()[i]:
            max=k.get_all()[i]
    for i in range(k.size()):
        b=k.get_all()[i]
        if b!=max:
            s.push(b)

    s.push(max)
    return  s



S = Stack()
s=Stack()

s.push(23)
s.push(53)
s.push(56)
s.push(19)
s.push(44)
s.push(22)
s.push(99)
s.push(44)
c=needmax(s,s)
d=s.get_all()
print(f"Preivious Stack",s.get_all())
print(f"Max value on top Stack",d)
# Out:
# Preivious Stack [23, 53, 56, 19, 44, 22, 99, 44, 23, 53, 56, 19, 44, 22, 44, 99]
# Max value on top Stack [23, 53, 56, 19, 44, 22, 99, 44, 23, 53, 56, 19, 44, 22, 44, 99]

# %%
# 4

class Stack():
    def __init__(self):
        self.item=[]
    def size(self):
        l=len(self.item)
        return l

    def isempty(self):
        if self.size()==0:
            return 1
        else:
            0
    def push(self,item):
        self.item.append(item)

    def pop(self):
        return self.item.pop()

    def peek(self):
        if not len(self.item)==0:
            return self.item[-1]

    def get_all(self):
        return self.item



def  balanceAB(s,s2):
    x=int(input("How many number you want to push in A? "))
    sumA=0
    for i in range(x):
        num1=0

        num1=int(input("Enter number: "))
        sumA=sumA+num1
        s.push(num1)



    y=int(input("How many number you want to push in B? "))
    sumB=0
    for i in range(y):
        num2=0

        num2=int(input("Enter number: "))
        sumB=sumB+num2
        s2.push(num2)
    print(f"StackA: {s.get_all()}")
    print(f"StackB: {s2.get_all()}")


    if sumA<sumB:
        j=sumB-sumA

        s.push(j)
    else:
        if sumB<sumA:
            z=sumA-sumB

            s2.push(z)

    return (s.get_all(),s2.get_all())
s=Stack()
s2=Stack()
x,y=balanceAB(s,s2)
print("Balanced Stack: ")
print(f"StackA:{x}")
print(f"StackB: {y}")

# %%
# 5

class Stack():
    def __init__(self):
        self.item=[]
    def size(self):
        l=len(self.item)
        return l

    def isEmpty(self):
        if self.size()==0:
            return 1
        else:
            0
    def push(self,item):
        self.item.append(item)

    def pop(self):
        return self.item.pop()

    def peek(self):
        if not len(self.item)==0:
            return self.item[-1]

    def get_all(self):
        return self.item


s=Stack()


def accending(s):

    import random
    for i in range(10):
        a=random.randint(0,100)
        s.push(a)
    for i in range(s.size()):
        for i in range((s.size()-1)):
            if s.get_all()[i]>s.get_all()[i+1]:
                s.get_all()[i],s.get_all()[i+1]=s.get_all()[i+1],s.get_all()[i]

    return s.get_all()
def entering(x,num):
    s.push(num)
    for i in range(s.size()):
        for i in range((s.size()-1)):
            if s.get_all()[i]>s.get_all()[i+1]:
                s.get_all()[i],s.get_all()[i+1]=s.get_all()[i+1],s.get_all()[i]
    return s.get_all()


num=int(input("Enter a value: "))

x=accending(s)
print(x)

y=entering(x,num)

print(y)
# Out:
# Enter a value: 10
# [2, 5, 6, 26, 34, 42, 67, 94, 95, 100]
# [2, 5, 6, 10, 26, 34, 42, 67, 94, 95, 100]

# %%
# 6

class Stack():
    def __init__(self):
        self.item=[]
    def size(self):
        l=len(self.item)
        return l

    def isempty(self):
        if self.size()==0:
            return 1
        else:
            0
    def push(self,item):
        self.item.append(item)

    def pop(self):
        return self.item.pop()

    def peek(self):
        if not len(self.item)==0:
            return self.item[-1]

    def get_all(self):
        return self.item



def  charecter(y,s,stack,x):
    for i in range (len(x)):
        s.push(x[i])


    update_str=" "
    while not ((s.size())==0):
        stack.push(s.pop())
    while not ((stack.size())==0):
        s.push(stack.peek())
        update_str+= stack.pop()

    print(f"You entered: {update_str}")
    while y!="no":
        y=(input("Want to undo word? say: yes or no "))
        updated_str=" "
        if y!="no":
            s.pop()
            while not ((s.size())==0):
                stack.push(s.pop())
            while not ((stack.size())==0):
                s.push(stack.peek())
                updated_str+= stack.pop()

            print(updated_str)

    return updated_str

s=Stack()
stack=Stack()
x=input("Input: ")
y=" "
a=charecter(y,s,stack,x)
print(a)
# Out:
# Input: Hello
# You entered:  Hello
# Want to undo word? say: yes or no Yes
#  Hello
# Want to undo word? say: yes or no Yes
#  Hell
# Want to undo word? say: yes or no No
#  Hel
# Want to undo word? say: yes or no No
#  He
# Want to undo word? say: yes or no No
#  H
# Want to undo word? say: yes or no Yes
#
# Want to undo word? say: yes or no no

# %%
# 7

from collections import deque
class Queue():
    def __init__(self):
        self.item=deque()
    def size(self):
        l=len(self.item)
        return l

    def isempty(self):
        if self.size()==0:
            return 1
        else:
            0
    def push(self,item):
        self.item.append(item)

    def pop(self):
        return self.item.pop()

    def peek(self):
        if not len(self.item)==0:
            return self.item[0]

    def get_all(self):
        return self.item
def reverse(q,q2,num):
    for i in range (num):
        x=int(input("Enter number: "))
        q.push(x)

    y=int(input("From whiche number you want to reverse: "))
    z=0
    while z<1:
        a=0
        while a< (q.size()):
            if y == q.get_all()[a]:
                m=a+1
                while m< (q.size()):
                    q2.push(q.get_all()[m])
                    m+=1
            a+=1


        a=0
        while a<(q2.size()) :
            q.pop()
            a=a+1
        a=0
        while not q.size()==0:

            q2.push(q.pop())
        z+=1

    return (q2.get_all())


q=Queue()
q2=Queue()
num=int(input("How many numbers you want to input: "))
s=reverse(q,q2,num)
print ("Output:",s)
# Out:
# How many numbers you want to input: 9
# Enter number: 10
# Enter number: 20
# Enter number: 30
# Enter number: 40
# Enter number: 50
# Enter number: 60
# Enter number: 70
# Enter number: 80
# Enter number: 90
# From whiche number you want to reverse: 60
# Output: deque([70, 80, 90, 60, 50, 40, 30, 20, 10])

# %%
# 8

class queue:
    def __init__(self):
        self.queue=[]
    def size(self):
        return len(self.queue)
    def isEmpty(self):
        if self.size()==0:
            return 1
        else:
            0
    def enqueue(self,queue):
        self.queue.append(queue)

    def dequeue(self):
        if self.isEmpty():
            print('queue is empty')
        else:
            self.queue.pop(0)
    def peak(self):
        if self.isEmpty():
            print('queue is empty')
        else:
            return self.queue[0]

num_members = int(input("Members to take donations from?: "))

a = queue()
b = queue()

for i in range(num_members):
    member_id = int(input("Enter member Id: "))
## even
    if member_id % 2 == 0:
        a.enqueue(member_id)
    else:
        b.enqueue(member_id)


print("Even number Id:", a.queue)
print("Odd number Id:", b.queue)
# Out:
# Members to take donations from?: 7
# Enter member Id: 2
# Enter member Id: 4
# Enter member Id: 7
# Enter member Id: 10
# Enter member Id: 1
# Enter member Id: 9
# Enter member Id: 11
# Even number Id: [2, 4, 10]
# Odd number Id: [7, 1, 9, 11]

# %%
# 9

from collections import deque


# Function to generate binary numbers between 1 and `n` using the
# queue data structure
def generate(n):

    # create an empty queue and enqueue 1
    q = deque()
    q.append('1')

    # run `n` times
    for i in range(n):
        # remove the front element
        front = str(q.popleft())

        # append 0 and 1 to the front element of the queue and
        # enqueue both strings
        q.append(front + '0')
        q.append(front + '1')

        # print the front element
        print(front)


if __name__ == '__main__':

    n = int(input("The Number : "))
    generate(n)
# Out:
# The Number : 5
# 1
# 10
# 11
# 100
# 101
